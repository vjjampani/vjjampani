# %% [markdown]
# ##  Author: Venkat Jagadeesh Jampani
# ##  Class: DSC540-T301 : Data Preparation
# ##  Date: Jul 03, 2022

# %% [markdown]
# ## Project Milestone2
# Cleaning/Formatting Flat File Source
# 1. Perform at least 5 data transformation and/or cleansing steps to your flat file data.
# 2. Examples: Replace Headers
# 3. Format data into a more readable format
# 4. Identify outliers and bad data
# 5. Find duplicates
# 6. Fix casing or inconsistent values
# 7. Conduct Fuzzy Matching

# %%
# load packages
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Data Source 1: Flat file data source

# %% [markdown]
# In the project there are there are 8 data sets ( flat files, csv files). That contain the different attributes of weather data.
# They are :
# 1. Temperature.csv
# 2. City Attributes
# 3. Humidity
# 4. Pressure
# 5. Weather description
# 6. wind dirrection
# 7. wind speed.
#
# In this mile stone will load the data and analylize and apply transformations on the data.

# %%
# Data Source 1 - Flat file data temperature
temperature_data = pd.read_csv('/Users/Jagadeesh/Desktop/SAI_MS/540/Project/Data/temperature.csv') 
temperature_data.head()
# Out:
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345  ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# ...

# %%
#complete data from temperature data file.
temperature_data.describe()
# Out:
#           Vancouver      Portland  San Francisco       Seattle   Los Angeles  \
# count  44458.000000  45252.000000   44460.000000  45250.000000  45250.000000
# mean     283.862654    284.992929     288.155821    284.409626    290.846116
# std        6.640131      7.452438       5.332862      6.547986      6.460823
# min      245.150000    262.370000     272.300000    263.780000    266.503667
# 25%      279.160000    279.850000     284.670000    279.830000    286.380000
# 50%      283.450000    284.320000     287.610000    283.940000    290.530000
# 75%      288.600785    289.451750     291.015167    288.530000    295.080000
# max      307.000000    312.520000     313.620000    307.300000    315.470000
#
#           San Diego     Las Vegas       Phoenix   Albuquerque        Denver  \
# count  45252.000000  45252.000000  45250.000000  45252.000000  45252.000000
# mean     290.215044    292.424887    295.493358    285.617856    282.839407
# ...

# %%
#Findinng the total count in temperature data set.
temperature_data.shape
# Out:
# (45253, 37)

# %%
#Drop the columns for the cities out side USA. from all the Data sets.
drop_columns = ['Vancouver','Toronto','Montreal','Beersheba','Tel Aviv District','Eilat','Haifa','Nahariyya','Jerusalem']
temp_data1 = temperature_data.drop(drop_columns, axis = 1)
temp_data1.head()
# Out:
#               datetime    Portland  San Francisco     Seattle  Los Angeles  \
# 0  2012-10-01 12:00:00         NaN            NaN         NaN          NaN
# 1  2012-10-01 13:00:00  282.080000     289.480000  281.800000   291.870000
# 2  2012-10-01 14:00:00  282.083252     289.474993  281.797217   291.868186
# 3  2012-10-01 15:00:00  282.091866     289.460618  281.789833   291.862844
# 4  2012-10-01 16:00:00  282.100481     289.446243  281.782449   291.857503
#
#     San Diego   Las Vegas     Phoenix  Albuquerque      Denver  ...  \
# 0         NaN         NaN         NaN          NaN         NaN  ...
# 1  291.530000  293.410000  296.600000   285.120000  284.610000  ...
# 2  291.533501  293.403141  296.608509   285.154558  284.607306  ...
# 3  291.543355  293.392177  296.631487   285.233952  284.599918  ...
# 4  291.553209  293.381213  296.654466   285.313345  284.592530  ...
#
#    Indianapolis     Atlanta     Detroit  Jacksonville   Charlotte       Miami  \
# ...

# %%
# Rename the columns : datetime to date_timme

temp_data2=pd.DataFrame(temperature_data)
temp_data2.rename(columns={'datetime': 'date_time'}, inplace=True)
temp_data2
# Out:
#                  date_time   Vancouver    Portland  San Francisco     Seattle  \
# 0      2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1      2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2      2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3      2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4      2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# ...                    ...         ...         ...            ...         ...
# 45248  2017-11-29 20:00:00         NaN  282.000000            NaN  280.820000
# 45249  2017-11-29 21:00:00         NaN  282.890000            NaN  281.650000
# 45250  2017-11-29 22:00:00         NaN  283.390000            NaN  282.750000
# 45251  2017-11-29 23:00:00         NaN  283.020000            NaN  282.960000
# 45252  2017-11-30 00:00:00         NaN  282.280000            NaN  283.040000
#
# ...

# %%
# rename the 2 word city names , replaced with underscore in between eg :'Los Angeles' to 'Los_Angeles'
temp_data3=pd.DataFrame(temperature_data)
temp_data3.rename(columns={'San Francisco': 'San_Francisco',  'Los Angeles': 'Los_Angeles','San Diego': 'San_Diego', 'Las Vegas': 'Las_Vegas',
 'San Antonio':'San_Antonio','Kansas City':'Kansas_City'}, inplace=True)
temp_data3
# Out:
#                  date_time   Vancouver    Portland  San_Francisco     Seattle  \
# 0      2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1      2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2      2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3      2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4      2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# ...                    ...         ...         ...            ...         ...
# 45248  2017-11-29 20:00:00         NaN  282.000000            NaN  280.820000
# 45249  2017-11-29 21:00:00         NaN  282.890000            NaN  281.650000
# 45250  2017-11-29 22:00:00         NaN  283.390000            NaN  282.750000
# 45251  2017-11-29 23:00:00         NaN  283.020000            NaN  282.960000
# 45252  2017-11-30 00:00:00         NaN  282.280000            NaN  283.040000
#
# ...

# %%
# check for any NaN in temperature data

print("The column datetime contains NaN - %r  " %temp_data3.date_time.isnull().values.any())

print("The column Vancouver contains NaN - %r  " %temp_data3.Vancouver.isnull().values.any())

print("The column Portland contains NaN - %r  " %temp_data3.Portland.isnull().values.any())

print("The column San Francisco contains NaN - %r  " %temp_data3.San_Francisco.isnull().values.any())
# Out:
# The column datetime contains NaN - False
# The column Vancouver contains NaN - True
# The column Portland contains NaN - True
# The column San Francisco contains NaN - True

# %%
#Find the missing values if any in the temperature data
temperature_data.isnull().sum()
# Out:
# date_time              0
# Vancouver            795
# Portland               1
# San Francisco        793
# Seattle                3
# Los Angeles            3
# San Diego              1
# Las Vegas              1
# Phoenix                3
# Albuquerque            1
# Denver                 1
# San Antonio            1
# Dallas                 4
# Houston                3
# Kansas City            1
# Minneapolis           13
# Saint Louis            1
# Chicago                3
# Nashville              2
# Indianapolis           7
# Atlanta                6
# Detroit                1
# Jacksonville           1
# Charlotte              3
# Miami                805
# Pittsburgh             3
# Toronto                1
# Philadelphia           3
# New York             793
# Montreal               3
# Boston                 3
# Beersheba            798
# Tel Aviv District    793
# Eilat                792
# Haifa                798
# Nahariyya            797
# Jerusalem            793
# ...

# %%
# find minimum values in all the collumns in temperature data
temperature_data.min()
# Out:
# date_time            2012-10-01 12:00:00
# Vancouver                         245.15
# Portland                          262.37
# San Francisco                      272.3
# Seattle                           263.78
# Los Angeles                   266.503667
# San Diego                     265.783333
# Las Vegas                     260.561333
# Phoenix                          266.059
# Albuquerque                   255.042333
# Denver                        247.727667
# San Antonio                       265.05
# Dallas                        261.610333
# Houston                           267.57
# Kansas City                   249.556333
# Minneapolis                   242.336667
# Saint Louis                       251.05
# Chicago                           248.89
# Nashville                     256.326333
# Indianapolis                  244.866333
# Atlanta                            259.5
# Detroit                       243.483333
# Jacksonville                      268.61
# ...

# %%
# find maximum values in all the collumns in temperature data
temperature_data.max()
# Out:
# date_time            2017-11-30 00:00:00
# Vancouver                          307.0
# Portland                          312.52
# San Francisco                     313.62
# Seattle                            307.3
# Los Angeles                       315.47
# San Diego                         313.36
# Las Vegas                         318.64
# Phoenix                           321.22
# Albuquerque                       312.71
# Denver                            313.75
# San Antonio                       313.66
# Dallas                             314.4
# Houston                           312.91
# Kansas City                       310.97
# Minneapolis                       308.24
# Saint Louis                       311.59
# Chicago                           308.48
# Nashville                         309.15
# Indianapolis                      312.04
# Atlanta                           310.76
# Detroit                           308.05
# Jacksonville                      310.15
# ...

# %%
# Check all the columns for the bad data
for column in temperature_data.columns:
    print(ascii(temperature_data[column][1]))
# Out:
# '2012-10-01 13:00:00'
# 284.63
# 282.08
# 289.48
# 281.8
# 291.87
# 291.53
# 293.41
# 296.6
# 285.12
# 284.61
# 289.29
# 289.74
# 288.27
# 289.98
# 286.87
# 286.18
# 284.01
# 287.41
# 283.85
# 294.03
# 284.03
# 298.17
# 288.65
# 299.72
# 281.0
# 286.26
# 285.63
# 288.22
# 285.83
# 287.17
# 307.59
# 305.47
# 310.58
# 304.4
# 304.4
# 303.5

# %%
#removed the data with NaN values
temperature_data.describe()
temperature_data = temperature_data.dropna()
temperature_data.shape
# Out:
# (44430, 37)

# %%
# Data Source 1 - Flat file data: city_attributes
city_data = pd.read_csv('/Users/Jagadeesh/Desktop/SAI_MS/540/Project/Data/city_attributes.csv') 
city_data.head()
# Out:
#             City        Country   Latitude   Longitude
# 0      Vancouver         Canada  49.249660 -123.119339
# 1       Portland  United States  45.523449 -122.676208
# 2  San Francisco  United States  37.774929 -122.419418
# 3        Seattle  United States  47.606209 -122.332069
# 4    Los Angeles  United States  34.052231 -118.243683

# %%
# Data Source 1 - Flat file data: humidity
humidity_data = pd.read_csv('/Users/Jagadeesh/Desktop/SAI_MS/540/Project/Data/humidity.csv') 
humidity_data.head()
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00       76.0      81.0           88.0     81.0
# 2  2012-10-01 14:00:00       76.0      80.0           87.0     80.0
# 3  2012-10-01 15:00:00       76.0      80.0           86.0     80.0
# 4  2012-10-01 16:00:00       77.0      80.0           85.0     79.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1         88.0       82.0       22.0     23.0         50.0  ...          71.0
# 2         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 3         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 4         88.0       81.0       21.0     23.0         49.0  ...          69.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# ...

# %%
#complete data from temperature data file.
humidity_data.describe()
# Out:
#           Vancouver      Portland  San Francisco       Seattle   Los Angeles  \
# count  43427.000000  44804.000000   44311.000000  44964.000000  45101.000000
# mean      81.895480     74.697616      76.875042     77.159038     62.773841
# std       14.522221     19.042656      17.396016     18.147464     21.818042
# min       12.000000     10.000000       6.000000     13.000000      5.000000
# 25%       73.000000     63.000000      68.000000     66.000000     48.000000
# 50%       86.000000     80.000000      81.000000     81.000000     66.000000
# 75%       93.000000     90.000000      89.000000     93.000000     81.000000
# max      100.000000    100.000000     100.000000    100.000000    100.000000
#
#           San Diego     Las Vegas       Phoenix   Albuquerque        Denver  \
# count  44909.000000  44411.000000  43945.000000  44543.000000  43445.000000
# mean      67.784809     31.937831     37.484424     45.186157     53.022557
# ...

# %%
#Findinng the total count in temperature data set.
humidity_data.shape
# Out:
# (45253, 37)

# %%
#Drop the columns for the cities out side USA. from all the Data sets.
drop_columns = ['Vancouver','Toronto','Montreal','Beersheba','Tel Aviv District','Eilat','Haifa','Nahariyya','Jerusalem']
humidity_data1 = humidity_data.drop(drop_columns, axis = 1)
humidity_data1.head()
# Out:
#               datetime  Portland  San Francisco  Seattle  Los Angeles  \
# 0  2012-10-01 12:00:00       NaN            NaN      NaN          NaN
# 1  2012-10-01 13:00:00      81.0           88.0     81.0         88.0
# 2  2012-10-01 14:00:00      80.0           87.0     80.0         88.0
# 3  2012-10-01 15:00:00      80.0           86.0     80.0         88.0
# 4  2012-10-01 16:00:00      80.0           85.0     79.0         88.0
#
#    San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  Indianapolis  \
# 0        NaN        NaN      NaN          NaN     NaN  ...           NaN
# 1       82.0       22.0     23.0         50.0    62.0  ...          76.0
# 2       81.0       21.0     23.0         49.0    62.0  ...          76.0
# 3       81.0       21.0     23.0         49.0    62.0  ...          76.0
# 4       81.0       21.0     23.0         49.0    62.0  ...          76.0
#
#    Atlanta  Detroit  Jacksonville  Charlotte  Miami  Pittsburgh  Philadelphia  \
# ...

# %%
# Rename the columns : datetime to date_timme
humidity_data2=pd.DataFrame(humidity_data1)
humidity_data2.rename(columns={'datetime': 'date_time'}, inplace=True)
humidity_data2
# Out:
#                  date_time  Portland  San Francisco  Seattle  Los Angeles  \
# 0      2012-10-01 12:00:00       NaN            NaN      NaN          NaN
# 1      2012-10-01 13:00:00      81.0           88.0     81.0         88.0
# 2      2012-10-01 14:00:00      80.0           87.0     80.0         88.0
# 3      2012-10-01 15:00:00      80.0           86.0     80.0         88.0
# 4      2012-10-01 16:00:00      80.0           85.0     79.0         88.0
# ...                    ...       ...            ...      ...          ...
# 45248  2017-11-29 20:00:00      81.0            NaN     93.0         24.0
# 45249  2017-11-29 21:00:00      71.0            NaN     87.0         21.0
# 45250  2017-11-29 22:00:00      71.0            NaN     93.0         23.0
# 45251  2017-11-29 23:00:00      71.0            NaN     87.0         14.0
# 45252  2017-11-30 00:00:00      76.0            NaN     75.0         56.0
#
#        San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  Indianapolis  \
# ...

# %%
# rename the 2 word city names , replaced with underscore in between eg :'Los Angeles' to 'Los_Angeles'
humidity_data3=pd.DataFrame(humidity_data2)
humidity_data3.rename(columns={'San Francisco': 'San_Francisco',  'Los Angeles': 'Los_Angeles','San Diego': 'San_Diego', 'Las Vegas': 'Las_Vegas',
 'San Antonio':'San_Antonio','Kansas City':'Kansas_City'}, inplace=True)
humidity_data3
# Out:
#                  date_time  Portland  San_Francisco  Seattle  Los_Angeles  \
# 0      2012-10-01 12:00:00       NaN            NaN      NaN          NaN
# 1      2012-10-01 13:00:00      81.0           88.0     81.0         88.0
# 2      2012-10-01 14:00:00      80.0           87.0     80.0         88.0
# 3      2012-10-01 15:00:00      80.0           86.0     80.0         88.0
# 4      2012-10-01 16:00:00      80.0           85.0     79.0         88.0
# ...                    ...       ...            ...      ...          ...
# 45248  2017-11-29 20:00:00      81.0            NaN     93.0         24.0
# 45249  2017-11-29 21:00:00      71.0            NaN     87.0         21.0
# 45250  2017-11-29 22:00:00      71.0            NaN     93.0         23.0
# 45251  2017-11-29 23:00:00      71.0            NaN     87.0         14.0
# 45252  2017-11-30 00:00:00      76.0            NaN     75.0         56.0
#
#        San_Diego  Las_Vegas  Phoenix  Albuquerque  Denver  ...  Indianapolis  \
# ...

# %%
# check for any NaN in humidity data

print("The column datetime contains NaN - %r  " %humidity_data3.date_time.isnull().values.any())

print("The column Vancouver contains NaN - %r  " %humidity_data3.Seattle.isnull().values.any())

print("The column Portland contains NaN - %r  " %humidity_data3.Portland.isnull().values.any())

print("The column San Francisco contains NaN - %r  " %humidity_data3.San_Francisco.isnull().values.any())
# Out:
# The column datetime contains NaN - False
# The column Vancouver contains NaN - True
# The column Portland contains NaN - True
# The column San Francisco contains NaN - True

# %%
#removed the data with NaN values
humidity_data4 = humidity_data3.dropna()

# %%
humidity_data4.shape
# Out:
# (37139, 28)

# %%
#Find the missing values if any in the humidity data
humidity_data3.isnull().sum()
# Out:
# date_time           0
# Portland          449
# San_Francisco     942
# Seattle           289
# Los_Angeles       152
# San_Diego         344
# Las_Vegas         842
# Phoenix          1308
# Albuquerque       710
# Denver           1808
# San_Antonio       564
# Dallas            319
# Houston           121
# Kansas_City       512
# Minneapolis       510
# Saint Louis      1289
# Chicago          1109
# Nashville         567
# Indianapolis      695
# Atlanta           422
# Detroit           862
# Jacksonville      209
# Charlotte         589
# Miami            1087
# Pittsburgh        522
# Philadelphia      624
# New York         1624
# Boston            449
# dtype: int64

# %%
# find minimum values in all the collumns in humidity data
humidity_data3.min()
# Out:
# date_time        2012-10-01 12:00:00
# Portland                        10.0
# San_Francisco                    6.0
# Seattle                         13.0
# Los_Angeles                      5.0
# San_Diego                        5.0
# Las_Vegas                        5.0
# Phoenix                          5.0
# Albuquerque                      5.0
# Denver                           5.0
# San_Antonio                      7.0
# Dallas                           9.0
# Houston                         12.0
# Kansas_City                     10.0
# Minneapolis                     13.0
# Saint Louis                      8.0
# Chicago                          6.0
# Nashville                       10.0
# Indianapolis                    16.0
# Atlanta                          6.0
# Detroit                         12.0
# Jacksonville                     7.0
# Charlotte                        8.0
# Miami                           12.0
# Pittsburgh                       5.0
# ...

# %%
# find maximium values in all the collumns in humidity data
humidity_data3.max()
# Out:
# date_time        2017-11-30 00:00:00
# Portland                       100.0
# San_Francisco                  100.0
# Seattle                        100.0
# Los_Angeles                    100.0
# San_Diego                      100.0
# Las_Vegas                      100.0
# Phoenix                        100.0
# Albuquerque                    100.0
# Denver                         100.0
# San_Antonio                    100.0
# Dallas                         100.0
# Houston                        100.0
# Kansas_City                    100.0
# Minneapolis                    100.0
# Saint Louis                    100.0
# Chicago                        100.0
# Nashville                      100.0
# Indianapolis                   100.0
# Atlanta                        100.0
# Detroit                        100.0
# Jacksonville                   100.0
# Charlotte                      100.0
# Miami                          100.0
# Pittsburgh                     100.0
# ...

# %%
# Check all the columns for the bad data
for column in humidity_data3.columns:
    print(ascii(humidity_data3[column][1]))
# Out:
# '2012-10-01 13:00:00'
# 81.0
# 88.0
# 81.0
# 88.0
# 82.0
# 22.0
# 23.0
# 50.0
# 62.0
# 93.0
# 87.0
# 93.0
# 71.0
# 67.0
# 71.0
# 71.0
# 100.0
# 76.0
# 94.0
# 76.0
# 88.0
# 87.0
# 83.0
# 93.0
# 71.0
# 58.0
# 68.0

# %%
humidity_data3.head()
# Out:
#              date_time  Portland  San_Francisco  Seattle  Los_Angeles  \
# 0  2012-10-01 12:00:00       NaN            NaN      NaN          NaN
# 1  2012-10-01 13:00:00      81.0           88.0     81.0         88.0
# 2  2012-10-01 14:00:00      80.0           87.0     80.0         88.0
# 3  2012-10-01 15:00:00      80.0           86.0     80.0         88.0
# 4  2012-10-01 16:00:00      80.0           85.0     79.0         88.0
#
#    San_Diego  Las_Vegas  Phoenix  Albuquerque  Denver  ...  Indianapolis  \
# 0        NaN        NaN      NaN          NaN     NaN  ...           NaN
# 1       82.0       22.0     23.0         50.0    62.0  ...          76.0
# 2       81.0       21.0     23.0         49.0    62.0  ...          76.0
# 3       81.0       21.0     23.0         49.0    62.0  ...          76.0
# 4       81.0       21.0     23.0         49.0    62.0  ...          76.0
#
#    Atlanta  Detroit  Jacksonville  Charlotte  Miami  Pittsburgh  Philadelphia  \
# ...

# %%
# Data Source 1 - Flat file data: pressure
pressure_data = pd.read_csv('/Users/Jagadeesh/Desktop/SAI_MS/540/Project/Data/pressure.csv') 
pressure_data.head()
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00        NaN    1024.0         1009.0   1027.0
# 2  2012-10-01 14:00:00        NaN    1024.0         1009.0   1027.0
# 3  2012-10-01 15:00:00        NaN    1024.0         1009.0   1028.0
# 4  2012-10-01 16:00:00        NaN    1024.0         1009.0   1028.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
# 2       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
# 3       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
# 4       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District   Eilat   Haifa  \
# ...

# %%
# Data Source 1 - Flat file data: weather_description
weather_description_data = pd.read_csv('/Users/Jagadeesh/Desktop/SAI_MS/540/Project/Data/weather_description.csv') 
weather_description_data.head()
# Out:
#               datetime      Vancouver          Portland San Francisco  \
# 0  2012-10-01 12:00:00            NaN               NaN           NaN
# 1  2012-10-01 13:00:00           mist  scattered clouds    light rain
# 2  2012-10-01 14:00:00  broken clouds  scattered clouds  sky is clear
# 3  2012-10-01 15:00:00  broken clouds  scattered clouds  sky is clear
# 4  2012-10-01 16:00:00  broken clouds  scattered clouds  sky is clear
#
#         Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  sky is clear          mist  sky is clear  sky is clear  sky is clear
# 2  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 3  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 4  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
#
#     Albuquerque  ...   Philadelphia    New York         Montreal  \
# ...

# %%
# Data Source 1 - Flat file data: wind_direction
wind_direction_data = pd.read_csv('/Users/Jagadeesh/Desktop/SAI_MS/540/Project/Data/wind_direction.csv') 
wind_direction_data.head()
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00        0.0       0.0          150.0      0.0
# 2  2012-10-01 14:00:00        6.0       4.0          147.0      2.0
# 3  2012-10-01 15:00:00       20.0      18.0          141.0     10.0
# 4  2012-10-01 16:00:00       34.0      31.0          135.0     17.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1          0.0        0.0        0.0     10.0        360.0  ...         270.0
# 2          0.0        0.0        8.0      9.0        360.0  ...         270.0
# 3          0.0        0.0       23.0      9.0        360.0  ...         271.0
# 4          0.0        0.0       37.0      9.0        360.0  ...         272.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# ...

# %%
# Data Source 1 - Flat file data: wind_speed
wind_speed_data = pd.read_csv('/Users/Jagadeesh/Desktop/SAI_MS/540/Project/Data/wind_speed.csv') 
wind_speed_data.head()
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00        0.0       0.0            2.0      0.0
# 2  2012-10-01 14:00:00        0.0       0.0            2.0      0.0
# 3  2012-10-01 15:00:00        0.0       0.0            2.0      0.0
# 4  2012-10-01 16:00:00        0.0       0.0            2.0      0.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1          0.0        0.0        0.0      2.0          4.0  ...           4.0
# 2          0.0        0.0        0.0      2.0          4.0  ...           4.0
# 3          0.0        0.0        0.0      2.0          4.0  ...           3.0
# 4          0.0        0.0        0.0      2.0          4.0  ...           3.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# ...

# %% [markdown]
# Will repeate the sametransformation like : changing column  names, removing cities outside USA and identifying the NaN and invalid data for the rest of the data sets.
